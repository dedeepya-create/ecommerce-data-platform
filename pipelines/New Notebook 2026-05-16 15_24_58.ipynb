# %%
import boto3

s3 = boto3.client(
    "s3",
    aws_access_key_id="",
    aws_secret_access_key=""
)

response = s3.list_objects_v2(Bucket="ecommerce-data-platform-dedi")
print("READ SUCCESS ✅")

# %%
s3.put_object(
    Bucket="ecommerce-data-platform-dedi",
    Key="test-folder/test.txt",
    Body="hello"
)

print("WRITE SUCCESS ✅")

# %%
# Step 1: Set credentials FIRST!
spark.conf.set("fs.s3a.access.key", "")
spark.conf.set("fs.s3a.secret.key", "")
spark.conf.set("fs.s3a.endpoint",   "s3.amazonaws.com")
spark.conf.set("fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")

# Step 2: Then read!
df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("")

print(f"Rows: {df.count()}")

# %%
df = spark.read.format("csv")\
    .option("header",True)\
    .option("inferschema",True)\
    .load("s3a://ecommerce-data-platform-dedi/Input_Data/customers/date=2026-05-16/customers.csv")

print (f"display {df.count()} rows ")
